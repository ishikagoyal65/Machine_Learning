# %% [markdown]
# <a href="https://colab.research.google.com/github/ishikagoyal65/Machine_Learning/blob/main/Simple_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/placement (1).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package (in lpa)')
# Out:
# Text(0, 0.5, 'package (in lpa)')

# %%
#input
X= df.iloc[:,0:1]
Y =df.iloc[:,-1]

# %%
#splitting the data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
#model training
from sklearn.linear_model import LinearRegression
lr =  LinearRegression() #object of the model
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train), color='red')
plt.xlabel('cgpa')
plt.ylabel('package (in lpa)')
# Out:
# Text(0, 0.5, 'package (in lpa)')

# %%
m = lr.coef_ #slope after the model is trained
c = lr.intercept_ #intercept after the model is trained

# %%
# y =mx+c (if we provide new  x (cgpa) we can predict the package)
